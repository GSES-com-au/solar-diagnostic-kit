# %% [markdown]
# # 1. Libraries Import

# %%
# ========================================================
# = Libraries import
# ========================================================
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns

# %%
FONT_SIZE = 16
rc={'font.size': FONT_SIZE, 'axes.labelsize': FONT_SIZE, 'legend.fontsize': FONT_SIZE,
    'axes.titlesize': FONT_SIZE, 'xtick.labelsize': FONT_SIZE, 'ytick.labelsize': FONT_SIZE}
plt.rc('font', weight='bold')

# %% [markdown]
# # 1 Read Data

# %% [markdown]
# ## 1.1. Read Meta Data Table

# %%
# raw meta data
df_sites = pd.read_csv('../input_data/SITE_nodeType_20230630.csv')
df_monitors = pd.read_csv('../input_data/MNTR_ddb_20230630.csv')
# df_monitors.head()

# %% [markdown]
# ## 1.2. Find SMA Monitors

# %%
# select monitor with fimer brand
df_SMA = df_monitors.loc[df_monitors['manufacturerApi']=='SMA', 'source']
SMA_monitor_list = df_SMA.str.split('|').str[1].values
print(len(SMA_monitor_list))
# Out:
# 775

# %%
df_sma = pd.read_csv('../preprocessed_data/monitors_DCdata/df_SMA_2.csv', index_col=0)
# df_sma.head()

# %% [markdown]
# # 2 Parameter Setting

# %%
# When working with MONITORS, we determine a time period:
time_start = '2022-05-01'
time_end = '2023-05-01'

# threshold values for fault detection
Uthreshold_diff = 0.2
Ithreshold_diff = 0.2
Pthreshold_diff = 0.2
time_threshold = 3

# to check the missing data
time_index5min = pd.date_range(start=pd.to_datetime(time_start), end=pd.to_datetime(time_end), freq='5min').tz_localize(None)
time_index5min
# Out:
# DatetimeIndex(['2022-05-01 00:00:00', '2022-05-01 00:05:00',
#                '2022-05-01 00:10:00', '2022-05-01 00:15:00',
#                '2022-05-01 00:20:00', '2022-05-01 00:25:00',
#                '2022-05-01 00:30:00', '2022-05-01 00:35:00',
#                '2022-05-01 00:40:00', '2022-05-01 00:45:00',
#                ...
#                '2023-04-30 23:15:00', '2023-04-30 23:20:00',
#                '2023-04-30 23:25:00', '2023-04-30 23:30:00',
#                '2023-04-30 23:35:00', '2023-04-30 23:40:00',
#                '2023-04-30 23:45:00', '2023-04-30 23:50:00',
#                '2023-04-30 23:55:00', '2023-05-01 00:00:00'],
#               dtype='datetime64[ns]', length=105121, freq='5T')

# %%
# check if a monitor in the downloaded file
sma_read_list = list(set(df_sma.columns.str.split(':').str[-1]))
if 'MNTR|5541098' in sma_read_list:
    print('yes')
# Out:
# yes

# %% [markdown]
# # 3 Single Monitor: Identify significant difference between different MPPTs

# %%
# ========================================================
# = Select elements in a array or list with a string
# ========================================================
def select_elements_with_string(iterable, search_string):
    """
    Select elements from the iterable that include the search_string.

    Args:
        iterable (iterable): The input iterable (list, NumPy array, etc.).
        search_string (str): The string to search for.

    Returns:
        list or numpy.ndarray: Elements from the iterable that include the search_string.
    """
    if isinstance(iterable, list):
        return [item for item in iterable if search_string in item]
    elif isinstance(iterable, np.ndarray):
        mask = np.array([search_string in item for item in iterable])
        return iterable[mask]
    else:
        raise ValueError("Input iterable type not supported")

# %%
# ========================================================
# = Read raw data & preprocess data
# ========================================================

def read_preprocess_monitor(df, MID, pvsize):
    '''
    df: index is time
    MID: MNTR|6905111
    '''
    ## == read data for the single monotor
    df_monitor = df.filter(regex='{}$'.format(MID))
    split_columns = df_monitor.columns.str.split(':').str[0]
    df_monitor.columns = split_columns
    df_monitor.reset_index(inplace=True)
    df_monitor['time'] = pd.to_datetime(df_monitor['time'].values)

    ## some columns related with the time
    metrics_name_list = df_monitor.columns.to_list()[1:]
    power_metrics_list = select_elements_with_string(iterable=metrics_name_list, search_string='.W')
    df_monitor['minute'] = df_monitor['time'].dt.minute
    df_monitor['hour'] = df_monitor['time'].dt.hour
    df_monitor['date'] = df_monitor['time'].dt.date
    df_monitor['date'] = df_monitor['date'].astype(pd.StringDtype())

    ## == processing data ====##
    # ========================================================
    # = Processing outliers based on the PV size
    # ========================================================
    if len(power_metrics_list) != 0:
        df_pre = df_monitor.copy()
        # outliers
        for power_metric in power_metrics_list:
            df_pre.loc[df_pre[power_metric]>1.2*pvsize, metrics_name_list] = np.NaN
        # ========================================================
        # = Filling up the missing data
        # ========================================================
        first_valid_idx = df_pre['Gen.W'].first_valid_index()
        last_valid_idx = df_pre['Gen.W'].last_valid_index()
        df_pre = df_pre.iloc[first_valid_idx: last_valid_idx+1, :]
        df_pre.fillna(method='ffill', inplace=True)
        return df_monitor, df_pre, metrics_name_list
    else:
        return None

# %% [markdown]
# ## 3.1. Find Significant difference

# %%
import itertools

# %%
# ========================================================
# = only consecutive significant points should be picked up
# ========================================================
def consecutive_comparison(df, threshold_value, diff_name, thred_time):
    '''
    df: df_pre
    threshold_value: threshold for significant identification, different values for different metrics (power, voltage, and current)
    diff_name: based on metrics (power, voltage, and current)
    thred_time: consective time period
    '''
    df['potential_'+diff_name] = df[diff_name]>threshold_value
    df['period'] = df['potential_'+diff_name].diff().ne(0).cumsum()
    df['duration'] = df.groupby('period')['potential_'+diff_name].transform('sum')
    df[diff_name+'_significant'] = df['potential_'+diff_name] & (df['duration']>=thred_time)
    df.drop(['potential_'+diff_name, 'period', 'duration'], axis=1, inplace=True)
    return df

# %%
def at_least_two_elements_in_list(my_list, other_list):
    count = sum(1 for element in my_list if element in other_list)
    return count >= 2

# %%
# ========================================================
# = Comparison between different phases and MPPTs
# ========================================================
def combination_compare(df, Uthreshold_value, Ithreshold_value, Pthreshold_value, DC_AC, thred_time, metrics_name_list):
    '''
    df: df
    Uthreshold_value, Ithreshold_value, Pthreshold_value: threshold values for different metrics
    DC_AC: "AC" or "DC"
    thred_time:
    mppt_power_list: calculate the MPPT number
    '''
    for metric, metric_per in [['P', 'W'], ['U', 'V'], ['I', 'A']]:
        if metric =='U':
            threshold_value = Uthreshold_value
        elif metric == 'I':
            threshold_value = Ithreshold_value
        else:
            threshold_value = Pthreshold_value
        # different phase
        if DC_AC == 'AC':
            metrics_list = select_elements_with_string(iterable=metrics_name_list, search_string='Inv.AC.{}.Ph'.format(metric))
            compare_metric = 'AC.{}{}.Ph'.format(metric, metric_per)
            comblen = len(metrics_list)
        else:
            metrics_list = select_elements_with_string(iterable=metrics_name_list, search_string='Inv.DC.{}.MPTT'.format(metric))
            compare_metric = 'DC.{}{}.MPPT'.format(metric, metric_per)
            comblen = len(metrics_list)
        if comblen >= 2:
            maxvalue_list = []
            for j in metrics_list:
                maxvalue_list.append(df[j].max())
            # print(maxvalue)
            combinations = list(itertools.combinations(np.arange(comblen), 2))
            # print(combinations)
            diff_name_list = []
            for comb in combinations:
                metric1 = metrics_list[comb[0]]
                metric2 = metrics_list[comb[1]]
                maxvalue1 = maxvalue_list[comb[0]]
                maxvalue2 = maxvalue_list[comb[1]]
                diff_name = '{}({} vs {})_diff'.format(compare_metric, comb[0]+1, comb[1]+1)
                diff_name_list.append(diff_name+'_significant')
                df[diff_name] = (df[metric1]/maxvalue1 - df[metric2]/maxvalue2).abs()
                df = consecutive_comparison(df=df, threshold_value=threshold_value, diff_name=diff_name, thred_time=thred_time)
            df[compare_metric+'_significant'] = False
            for diff_name_sig in diff_name_list:
                df[compare_metric+'_significant'] = df[compare_metric+'_significant']|df[diff_name_sig]
    return df

# %%
# ========================================================
# = Comparison between different phases and MPPTs
# ========================================================
def compare_diff(df, Uthreshold_value, Ithreshold_value, Pthreshold_value, thred_time, metrics_name_list):
    for adc_id in ['AC', 'DC']: 
        df = combination_compare(df=df, Uthreshold_value=Uthreshold_value, Ithreshold_value=Ithreshold_value,  
                                 Pthreshold_value=Pthreshold_value, DC_AC=adc_id, thred_time=thred_time, metrics_name_list=metrics_name_list)
    return df

# %%
def plot_results(metrics_name_list, df_plot, save_path, save_name):
    fig, axes = plt.subplots(nrows=len(metrics_name_list), figsize=(26, 4*len(metrics_name_list)))
    for i, icol in enumerate(metrics_name_list):
        if 'AC.' in icol:
            if 'P.' in icol:
                compare_metric = 'AC.PW.Ph_significant'
            elif 'Gen.W' in icol:
                compare_metric = 'AC.PW.Ph_significant'
            elif 'U.' in icol:
                compare_metric = 'AC.UV.Ph_significant'
            else:
                compare_metric = 'AC.IA.Ph_significant'
        elif 'DC' in icol:
            if 'P.' in icol:
                compare_metric = 'DC.PW.MPPT_significant'
            elif 'U.' in icol:
                compare_metric = 'DC.UV.MPPT_significant'
            elif 'I.' in icol:
                compare_metric = 'DC.IA.MPPT_significant'
            else:
                compare_metric = None  
        else:
            compare_metric = None
        print(icol, compare_metric)
        sns.lineplot(data=df_plot, x ='time_str', y=icol, ax=axes[i])
        if compare_metric != None:
            sns.scatterplot(data=df_plot, x='time_str', y=icol, hue=compare_metric, ax=axes[i])
        axes[i].set_xticks(axes[i].get_xticks()[::288])
        # for label in axes[i].get_xticklabels():
        #     label.set_rotation(rota)
    
    plt.savefig(save_path+'/{}'.format(save_name))
    plt.close()

# %%
def pltsignicant(metrics_name_list, df_sig, df_compare, save_path, MID):
    # plot
    cols_list_all = ['AC.PW.Ph_significant', 'AC.UV.Ph_significant', 'AC.IA.Ph_significant', 'DC.PW.MPPT_significant', 'DC.UV.MPPT_significant', 'DC.IA.MPPT_significant']
    cols_list = df_sig.columns[df_sig.columns.isin(cols_list_all)].values

    df_save_path = df_sig[cols_list].copy()
    # print(df_save_path.columns.to_list())
    df_save_path = df_save_path.loc[:, ~(df_save_path == False).all()]
    # print(df_save_path.columns.to_list())
    file_name = ''
    if any('AC' in column for column in df_save_path.columns): #and any('DC' in column for column in df_save_path.columns):
        file_name = file_name + 'AC'
    if any('PW.Ph' in column for column in df_save_path.columns):
        file_name = file_name + '_Power'
    if any('UV.Ph' in column for column in df_save_path.columns):
        file_name = file_name + '_Voltage'
    if any('IA.Ph' in column for column in df_save_path.columns):
        file_name = file_name + '_Current'
    if any('DC' in column for column in df_save_path.columns):
        file_name = file_name + 'DC'
    if any('PW.MPPT' in column for column in df_save_path.columns):
        file_name = file_name + '_Power'
    if any('UV.MPPT' in column for column in df_save_path.columns):
        file_name = file_name + '_Voltage'
    if any('IA.MPPT' in column for column in df_save_path.columns):
        file_name = file_name + '_Current'
    # print('file_name:', file_name)
    save_file = save_path + '/{}'.format(file_name)
    if not os.path.exists(save_file):
        os.makedirs(save_file)
    date_significant_list = df_sig['date'].unique()
    print('significant days:', len(date_significant_list))
    df_plot_sig = df_compare[df_compare['date'].isin(date_significant_list)].copy()
    df_plot_sig['time_str'] = df_plot_sig['time'].dt.strftime('%Y-%m-%d %H:%M:%S')
    if len(date_significant_list) > 20:
        plot_results(metrics_name_list, df_plot=df_plot_sig[df_plot_sig['date'].isin(date_significant_list[0:20])], save_path=save_file, save_name='{}.png'.format(MID))
        print('more than 20 days are experienced significant difference')
        date_sigpower_list = df_sig.loc[df_sig['DC.PW.MPPT_significant']==True, 'date'].unique()
        if len(date_sigpower_list)>10:
            df_plot_sigP = df_compare[df_compare['date'].isin(date_sigpower_list[0:10])].copy()
        else:
            df_plot_sigP = df_compare[df_compare['date'].isin(date_sigpower_list)].copy()
        if len(df_plot_sigP)!= 0:
            df_plot_sigP['time_str'] = df_plot_sig['time'].dt.strftime('%Y-%m-%d %H:%M:%S')
            plot_results(metrics_name_list, df_plot=df_plot_sigP, save_path=save_file, save_name='{}_power_sig.png'.format(MID))
    else:
        plot_results(metrics_name_list, df_plot=df_plot_sig, save_path=save_file, save_name='{}.png'.format(MID))

# %% [markdown]
# ## 3.2. Loop for all monitors

# %%
save_path = 'plots/SMA_significant_diff/'
if not os.path.exists(save_path):
    os.makedirs(save_path)

for i, MIDname in enumerate(sma_read_list):
    MID = MIDname.split('|')[1]
    pv_size = df_monitors.loc[df_monitors['source']== MIDname, 'pvSizeWatt'].values[0]
    print('='*50)
    print('{}: MID: {}, pv_size: {}'.format(i, MIDname, pv_size))
    # read & preprocess data
    df_read_preprocess = read_preprocess_monitor(df=df_sma, MID=MID, pvsize=pv_size)
    if df_read_preprocess is not None:
        df_raw, df_pre, metrics_name_list = df_read_preprocess
        print('metrics_name_list:', metrics_name_list)
        df_compare = df_pre.copy()
        df_compare = compare_diff(df=df_compare, Uthreshold_value=Uthreshold_diff, Ithreshold_value=Ithreshold_diff, 
                                Pthreshold_value=Pthreshold_diff, thred_time=time_threshold, metrics_name_list=metrics_name_list)
        
        # find significant dates
        filter_df = df_compare.filter(regex='_significant')
        comapre_columns_list = filter_df.columns.to_list()
        filter_df['time'] = df_compare['time'].values
        filter_df['date'] = filter_df['time'].dt.date.astype(str)
        df_sig = filter_df[filter_df[comapre_columns_list].any(axis=1)]
        # df_sig
        if len(df_sig) != 0:
            pltsignicant(metrics_name_list = metrics_name_list, df_sig=df_sig, df_compare=df_compare, 
                        save_path=save_path, MID=MID)
# Out:
# ==================================================
# 0: MID: MNTR|895040, pv_size: 27770
# Gen.W
# Inv.AC.P.Ph1.W
# Inv.AC.P.Ph2.W
# Inv.AC.P.Ph3.W
# Inv.DC.P.MPTT1.W
# Inv.DC.P.MPTT2.W
# metrics_name_list: ['Gen.W', 'Inv.AC.P.Ph1.W', 'Inv.AC.P.Ph2.W', 'Inv.AC.P.Ph3.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.U.Ph2.V', 'Inv.AC.U.Ph3.V', 'Inv.AC.I.Ph1.A', 'Inv.AC.I.Ph2.A', 'Inv.AC.I.Ph3.A', 'Inv.DC.P.MPTT1.W', 'Inv.DC.P.MPTT2.W', 'Inv.DC.U.MPTT1.V', 'Inv.DC.U.MPTT2.V', 'Inv.DC.I.MPTT1.A', 'Inv.DC.I.MPTT2.A', 'Inv.DC.R.Ohm']
# significant days: 5
# Gen.W None
# Inv.AC.P.Ph1.W AC.PW.Ph_significant
# Inv.AC.P.Ph2.W AC.PW.Ph_significant
# Inv.AC.P.Ph3.W AC.PW.Ph_significant
# Inv.AC.U.Ph1.V AC.UV.Ph_significant
# Inv.AC.U.Ph2.V AC.UV.Ph_significant
# Inv.AC.U.Ph3.V AC.UV.Ph_significant
# Inv.AC.I.Ph1.A AC.IA.Ph_significant
# Inv.AC.I.Ph2.A AC.IA.Ph_significant
# Inv.AC.I.Ph3.A AC.IA.Ph_significant
# Inv.DC.P.MPTT1.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT2.W DC.PW.MPPT_significant
# Inv.DC.U.MPTT1.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT2.V DC.UV.MPPT_significant
# Inv.DC.I.MPTT1.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT2.A DC.IA.MPPT_significant
# Inv.DC.R.Ohm None
# ==================================================
# 1: MID: MNTR|1a857cbb-6f0f-4fb9-9e01-7562ba8a419b, pv_size: 65710
# Gen.W
# metrics_name_list: ['Gen.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.I.Ph1.A', 'Inv.DC.U.MPTT1.V', 'Inv.DC.I.MPTT1.A']
# ==================================================
# 2: MID: MNTR|598b4099-fe82-401c-8a0b-193df8eb755b, pv_size: 27770
# Gen.W
# metrics_name_list: ['Gen.W']
# ==================================================
# 3: MID: MNTR|5332898, pv_size: 27710
# Gen.W
# Inv.AC.P.Ph1.W
# Inv.AC.P.Ph2.W
# Inv.AC.P.Ph3.W
# Inv.DC.P.MPTT1.W
# Inv.DC.P.MPTT2.W
# metrics_name_list: ['Gen.W', 'Inv.AC.P.Ph1.W', 'Inv.AC.P.Ph2.W', 'Inv.AC.P.Ph3.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.U.Ph2.V', 'Inv.AC.U.Ph3.V', 'Inv.AC.I.Ph1.A', 'Inv.AC.I.Ph2.A', 'Inv.AC.I.Ph3.A', 'Inv.DC.P.MPTT1.W', 'Inv.DC.P.MPTT2.W', 'Inv.DC.U.MPTT1.V', 'Inv.DC.U.MPTT2.V', 'Inv.DC.I.MPTT1.A', 'Inv.DC.I.MPTT2.A', 'Inv.DC.R.Ohm']
# ==================================================
# 4: MID: MNTR|2eb1b336-c6c6-4851-b723-edcc9916ab1c, pv_size: 27770
# Gen.W
# metrics_name_list: ['Gen.W']
# ==================================================
# 5: MID: MNTR|aa5e41c9-a5ce-47fa-a858-00dc22c4733f, pv_size: 63800
# Gen.W
# metrics_name_list: ['Gen.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.I.Ph1.A', 'Inv.DC.U.MPTT1.V']
# ==================================================
# 6: MID: MNTR|ef04ad54-3cc3-429e-bd2f-ffada09fe9b9, pv_size: 74240
# Gen.W
# metrics_name_list: ['Gen.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.I.Ph1.A', 'Inv.DC.U.MPTT1.V']
# ==================================================
# 7: MID: MNTR|fe605f0e-06cd-4c24-8704-bcd7bf4e7e4b, pv_size: 61940
# Gen.W
# metrics_name_list: ['Gen.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.I.Ph1.A']
# ==================================================
# 8: MID: MNTR|8732977, pv_size: 99800
# Gen.W
# Inv.DC.P.MPTT1.W
# Inv.DC.P.MPTT2.W
# Inv.DC.P.MPTT3.W
# Inv.DC.P.MPTT4.W
# Inv.DC.P.MPTT5.W
# Inv.DC.P.MPTT6.W
# Inv.DC.P.MPTT7.W
# Inv.DC.P.MPTT8.W
# Inv.DC.P.MPTT9.W
# Inv.DC.P.MPTT10.W
# Inv.DC.P.MPTT11.W
# Inv.DC.P.MPTT12.W
# metrics_name_list: ['Gen.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.U.Ph2.V', 'Inv.AC.U.Ph3.V', 'Inv.AC.I.Ph1.A', 'Inv.AC.I.Ph2.A', 'Inv.AC.I.Ph3.A', 'Inv.DC.P.MPTT1.W', 'Inv.DC.P.MPTT2.W', 'Inv.DC.P.MPTT3.W', 'Inv.DC.P.MPTT4.W', 'Inv.DC.P.MPTT5.W', 'Inv.DC.P.MPTT6.W', 'Inv.DC.P.MPTT7.W', 'Inv.DC.P.MPTT8.W', 'Inv.DC.P.MPTT9.W', 'Inv.DC.P.MPTT10.W', 'Inv.DC.P.MPTT11.W', 'Inv.DC.P.MPTT12.W', 'Inv.DC.U.MPTT1.V', 'Inv.DC.U.MPTT2.V', 'Inv.DC.U.MPTT3.V', 'Inv.DC.U.MPTT4.V', 'Inv.DC.U.MPTT5.V', 'Inv.DC.U.MPTT6.V', 'Inv.DC.U.MPTT7.V', 'Inv.DC.U.MPTT8.V', 'Inv.DC.U.MPTT9.V', 'Inv.DC.U.MPTT10.V', 'Inv.DC.U.MPTT11.V', 'Inv.DC.U.MPTT12.V', 'Inv.DC.I.MPTT1.A', 'Inv.DC.I.MPTT2.A', 'Inv.DC.I.MPTT3.A', 'Inv.DC.I.MPTT4.A', 'Inv.DC.I.MPTT5.A', 'Inv.DC.I.MPTT6.A', 'Inv.DC.I.MPTT7.A', 'Inv.DC.I.MPTT8.A', 'Inv.DC.I.MPTT9.A', 'Inv.DC.I.MPTT10.A', 'Inv.DC.I.MPTT11.A', 'Inv.DC.I.MPTT12.A', 'Inv.DC.R.Ohm']
# significant days: 6
# Gen.W None
# Inv.AC.U.Ph1.V AC.UV.Ph_significant
# Inv.AC.U.Ph2.V AC.UV.Ph_significant
# Inv.AC.U.Ph3.V AC.UV.Ph_significant
# Inv.AC.I.Ph1.A AC.IA.Ph_significant
# Inv.AC.I.Ph2.A AC.IA.Ph_significant
# Inv.AC.I.Ph3.A AC.IA.Ph_significant
# Inv.DC.P.MPTT1.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT2.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT3.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT4.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT5.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT6.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT7.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT8.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT9.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT10.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT11.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT12.W DC.PW.MPPT_significant
# Inv.DC.U.MPTT1.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT2.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT3.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT4.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT5.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT6.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT7.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT8.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT9.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT10.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT11.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT12.V DC.UV.MPPT_significant
# Inv.DC.I.MPTT1.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT2.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT3.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT4.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT5.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT6.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT7.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT8.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT9.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT10.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT11.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT12.A DC.IA.MPPT_significant
# Inv.DC.R.Ohm None
# ==================================================
# 9: MID: MNTR|3516435, pv_size: 24990
# Gen.W
# Inv.AC.P.Ph1.W
# Inv.AC.P.Ph2.W
# Inv.AC.P.Ph3.W
# metrics_name_list: ['Gen.W', 'Inv.AC.P.Ph1.W', 'Inv.AC.P.Ph2.W', 'Inv.AC.P.Ph3.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.U.Ph2.V', 'Inv.AC.U.Ph3.V', 'Inv.AC.I.Ph1.A', 'Inv.AC.I.Ph2.A', 'Inv.AC.I.Ph3.A']
# ==================================================
# 10: MID: MNTR|0896593a-2e94-445b-8a89-db937e496c1d, pv_size: 27770
# Gen.W
# metrics_name_list: ['Gen.W', 'Inv.DC.U.MPTT1.V', 'Inv.DC.U.MPTT2.V', 'Inv.DC.I.MPTT1.A', 'Inv.DC.I.MPTT2.A']
# significant days: 3
# Gen.W None
# Inv.DC.U.MPTT1.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT2.V DC.UV.MPPT_significant
# Inv.DC.I.MPTT1.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT2.A DC.IA.MPPT_significant
# ==================================================
# 11: MID: MNTR|eacfc0ed-a6ce-40f1-981c-11c80692f0b7, pv_size: 20580
# Gen.W
# metrics_name_list: ['Gen.W']
# ==================================================
# 12: MID: MNTR|5242935, pv_size: 27770
# Gen.W
# Inv.AC.P.Ph1.W
# Inv.AC.P.Ph2.W
# Inv.AC.P.Ph3.W
# Inv.DC.P.MPTT1.W
# Inv.DC.P.MPTT2.W
# metrics_name_list: ['Gen.W', 'Inv.AC.P.Ph1.W', 'Inv.AC.P.Ph2.W', 'Inv.AC.P.Ph3.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.U.Ph2.V', 'Inv.AC.U.Ph3.V', 'Inv.AC.I.Ph1.A', 'Inv.AC.I.Ph2.A', 'Inv.AC.I.Ph3.A', 'Inv.DC.P.MPTT1.W', 'Inv.DC.P.MPTT2.W', 'Inv.DC.U.MPTT1.V', 'Inv.DC.U.MPTT2.V', 'Inv.DC.I.MPTT1.A', 'Inv.DC.I.MPTT2.A', 'Inv.DC.R.Ohm']
# ==================================================
# 13: MID: MNTR|25982a13-c5c3-4b00-80a0-68bfd497eaa8, pv_size: 67760
# Gen.W
# metrics_name_list: ['Gen.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.I.Ph1.A', 'Inv.DC.U.MPTT1.V', 'Inv.DC.I.MPTT1.A']
# ==================================================
# 14: MID: MNTR|325aa25d-4122-4a0f-b159-56598d9cf33d, pv_size: 78440
# Gen.W
# metrics_name_list: ['Gen.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.I.Ph1.A', 'Inv.DC.U.MPTT1.V']
# ==================================================
# 15: MID: MNTR|5556050, pv_size: 26560
# Gen.W
# Inv.AC.P.Ph1.W
# Inv.AC.P.Ph2.W
# Inv.AC.P.Ph3.W
# Inv.DC.P.MPTT1.W
# Inv.DC.P.MPTT2.W
# metrics_name_list: ['Gen.W', 'Inv.AC.P.Ph1.W', 'Inv.AC.P.Ph2.W', 'Inv.AC.P.Ph3.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.U.Ph2.V', 'Inv.AC.U.Ph3.V', 'Inv.AC.I.Ph1.A', 'Inv.AC.I.Ph2.A', 'Inv.AC.I.Ph3.A', 'Inv.DC.P.MPTT1.W', 'Inv.DC.P.MPTT2.W', 'Inv.DC.U.MPTT1.V', 'Inv.DC.U.MPTT2.V', 'Inv.DC.I.MPTT1.A', 'Inv.DC.I.MPTT2.A', 'Inv.DC.R.Ohm']
# significant days: 159
# Gen.W None
# Inv.AC.P.Ph1.W AC.PW.Ph_significant
# Inv.AC.P.Ph2.W AC.PW.Ph_significant
# Inv.AC.P.Ph3.W AC.PW.Ph_significant
# Inv.AC.U.Ph1.V AC.UV.Ph_significant
# Inv.AC.U.Ph2.V AC.UV.Ph_significant
# Inv.AC.U.Ph3.V AC.UV.Ph_significant
# Inv.AC.I.Ph1.A AC.IA.Ph_significant
# Inv.AC.I.Ph2.A AC.IA.Ph_significant
# Inv.AC.I.Ph3.A AC.IA.Ph_significant
# Inv.DC.P.MPTT1.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT2.W DC.PW.MPPT_significant
# Inv.DC.U.MPTT1.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT2.V DC.UV.MPPT_significant
# Inv.DC.I.MPTT1.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT2.A DC.IA.MPPT_significant
# Inv.DC.R.Ohm None
# more than 20 days are experienced significant difference
# Gen.W None
# Inv.AC.P.Ph1.W AC.PW.Ph_significant
# Inv.AC.P.Ph2.W AC.PW.Ph_significant
# Inv.AC.P.Ph3.W AC.PW.Ph_significant
# Inv.AC.U.Ph1.V AC.UV.Ph_significant
# Inv.AC.U.Ph2.V AC.UV.Ph_significant
# Inv.AC.U.Ph3.V AC.UV.Ph_significant
# Inv.AC.I.Ph1.A AC.IA.Ph_significant
# Inv.AC.I.Ph2.A AC.IA.Ph_significant
# Inv.AC.I.Ph3.A AC.IA.Ph_significant
# Inv.DC.P.MPTT1.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT2.W DC.PW.MPPT_significant
# Inv.DC.U.MPTT1.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT2.V DC.UV.MPPT_significant
# Inv.DC.I.MPTT1.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT2.A DC.IA.MPPT_significant
# Inv.DC.R.Ohm None
# ==================================================
# 16: MID: MNTR|ad5263d3-5cc4-4cba-a536-179772cc5eb1, pv_size: 27770
# Gen.W
# metrics_name_list: ['Gen.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.U.Ph2.V', 'Inv.AC.U.Ph3.V', 'Inv.AC.I.Ph1.A', 'Inv.AC.I.Ph2.A', 'Inv.AC.I.Ph3.A']
# ==================================================
# 17: MID: MNTR|77ba6249-4275-4399-a167-ffa466756931, pv_size: 93980
# Gen.W
# metrics_name_list: ['Gen.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.I.Ph1.A']
# ==================================================
# 18: MID: MNTR|987654359, pv_size: 26100
# Gen.W
# metrics_name_list: ['Gen.W']
# ==================================================
# 19: MID: MNTR|6ab15343-e0ab-4034-8673-afe9ba8c7bbd, pv_size: 61460
# Gen.W
# Inv.DC.P.MPTT1.W
# Inv.DC.P.MPTT2.W
# Inv.DC.P.MPTT3.W
# Inv.DC.P.MPTT4.W
# Inv.DC.P.MPTT5.W
# Inv.DC.P.MPTT6.W
# metrics_name_list: ['Gen.W', 'Inv.DC.P.MPTT1.W', 'Inv.DC.P.MPTT2.W', 'Inv.DC.P.MPTT3.W', 'Inv.DC.P.MPTT4.W', 'Inv.DC.P.MPTT5.W', 'Inv.DC.P.MPTT6.W']
# significant days: 4
# Gen.W None
# Inv.DC.P.MPTT1.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT2.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT3.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT4.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT5.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT6.W DC.PW.MPPT_significant
# ==================================================
# 20: MID: MNTR|228ae2ed-bb56-4136-88ff-327771982a03, pv_size: 58060
# Gen.W
# Inv.DC.P.MPTT1.W
# Inv.DC.P.MPTT2.W
# Inv.DC.P.MPTT3.W
# Inv.DC.P.MPTT4.W
# Inv.DC.P.MPTT5.W
# Inv.DC.P.MPTT6.W
# metrics_name_list: ['Gen.W', 'Inv.DC.P.MPTT1.W', 'Inv.DC.P.MPTT2.W', 'Inv.DC.P.MPTT3.W', 'Inv.DC.P.MPTT4.W', 'Inv.DC.P.MPTT5.W', 'Inv.DC.P.MPTT6.W']
# significant days: 5
# Gen.W None
# Inv.DC.P.MPTT1.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT2.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT3.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT4.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT5.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT6.W DC.PW.MPPT_significant
# ==================================================
# 21: MID: MNTR|1036314, pv_size: 27670
# Gen.W
# Inv.AC.P.Ph1.W
# Inv.AC.P.Ph2.W
# Inv.AC.P.Ph3.W
# Inv.DC.P.MPTT1.W
# Inv.DC.P.MPTT2.W
# metrics_name_list: ['Gen.W', 'Inv.AC.P.Ph1.W', 'Inv.AC.P.Ph2.W', 'Inv.AC.P.Ph3.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.U.Ph2.V', 'Inv.AC.U.Ph3.V', 'Inv.AC.I.Ph1.A', 'Inv.AC.I.Ph2.A', 'Inv.AC.I.Ph3.A', 'Inv.DC.P.MPTT1.W', 'Inv.DC.P.MPTT2.W', 'Inv.DC.U.MPTT1.V', 'Inv.DC.U.MPTT2.V', 'Inv.DC.I.MPTT1.A', 'Inv.DC.I.MPTT2.A', 'Inv.DC.R.Ohm']
# significant days: 1
# Gen.W None
# Inv.AC.P.Ph1.W AC.PW.Ph_significant
# Inv.AC.P.Ph2.W AC.PW.Ph_significant
# Inv.AC.P.Ph3.W AC.PW.Ph_significant
# Inv.AC.U.Ph1.V AC.UV.Ph_significant
# Inv.AC.U.Ph2.V AC.UV.Ph_significant
# Inv.AC.U.Ph3.V AC.UV.Ph_significant
# Inv.AC.I.Ph1.A AC.IA.Ph_significant
# Inv.AC.I.Ph2.A AC.IA.Ph_significant
# Inv.AC.I.Ph3.A AC.IA.Ph_significant
# Inv.DC.P.MPTT1.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT2.W DC.PW.MPPT_significant
# Inv.DC.U.MPTT1.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT2.V DC.UV.MPPT_significant
# Inv.DC.I.MPTT1.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT2.A DC.IA.MPPT_significant
# Inv.DC.R.Ohm None
# ==================================================
# 22: MID: MNTR|6744beaf-1aa0-444f-af7b-6ed8c12326eb, pv_size: 66730
# Gen.W
# metrics_name_list: ['Gen.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.I.Ph1.A', 'Inv.DC.U.MPTT1.V']
# ==================================================
# 23: MID: MNTR|10fd749f-e6d8-49b9-8b74-254317cc9546, pv_size: 12280
# Gen.W
# metrics_name_list: ['Gen.W']
# ==================================================
# 24: MID: MNTR|7482361, pv_size: 99900
# Gen.W
# Inv.DC.P.MPTT1.W
# Inv.DC.P.MPTT2.W
# Inv.DC.P.MPTT3.W
# Inv.DC.P.MPTT4.W
# Inv.DC.P.MPTT5.W
# Inv.DC.P.MPTT6.W
# Inv.DC.P.MPTT7.W
# Inv.DC.P.MPTT8.W
# Inv.DC.P.MPTT9.W
# Inv.DC.P.MPTT10.W
# Inv.DC.P.MPTT11.W
# Inv.DC.P.MPTT12.W
# metrics_name_list: ['Gen.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.U.Ph2.V', 'Inv.AC.U.Ph3.V', 'Inv.AC.I.Ph1.A', 'Inv.AC.I.Ph2.A', 'Inv.AC.I.Ph3.A', 'Inv.DC.P.MPTT1.W', 'Inv.DC.P.MPTT2.W', 'Inv.DC.P.MPTT3.W', 'Inv.DC.P.MPTT4.W', 'Inv.DC.P.MPTT5.W', 'Inv.DC.P.MPTT6.W', 'Inv.DC.P.MPTT7.W', 'Inv.DC.P.MPTT8.W', 'Inv.DC.P.MPTT9.W', 'Inv.DC.P.MPTT10.W', 'Inv.DC.P.MPTT11.W', 'Inv.DC.P.MPTT12.W', 'Inv.DC.U.MPTT1.V', 'Inv.DC.U.MPTT2.V', 'Inv.DC.U.MPTT3.V', 'Inv.DC.U.MPTT4.V', 'Inv.DC.U.MPTT5.V', 'Inv.DC.U.MPTT6.V', 'Inv.DC.U.MPTT7.V', 'Inv.DC.U.MPTT8.V', 'Inv.DC.U.MPTT9.V', 'Inv.DC.U.MPTT10.V', 'Inv.DC.U.MPTT11.V', 'Inv.DC.U.MPTT12.V', 'Inv.DC.I.MPTT1.A', 'Inv.DC.I.MPTT2.A', 'Inv.DC.I.MPTT3.A', 'Inv.DC.I.MPTT4.A', 'Inv.DC.I.MPTT5.A', 'Inv.DC.I.MPTT6.A', 'Inv.DC.I.MPTT7.A', 'Inv.DC.I.MPTT8.A', 'Inv.DC.I.MPTT9.A', 'Inv.DC.I.MPTT10.A', 'Inv.DC.I.MPTT11.A', 'Inv.DC.I.MPTT12.A', 'Inv.DC.R.Ohm']
# significant days: 6
# Gen.W None
# Inv.AC.U.Ph1.V AC.UV.Ph_significant
# Inv.AC.U.Ph2.V AC.UV.Ph_significant
# Inv.AC.U.Ph3.V AC.UV.Ph_significant
# Inv.AC.I.Ph1.A AC.IA.Ph_significant
# Inv.AC.I.Ph2.A AC.IA.Ph_significant
# Inv.AC.I.Ph3.A AC.IA.Ph_significant
# Inv.DC.P.MPTT1.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT2.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT3.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT4.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT5.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT6.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT7.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT8.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT9.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT10.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT11.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT12.W DC.PW.MPPT_significant
# Inv.DC.U.MPTT1.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT2.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT3.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT4.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT5.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT6.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT7.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT8.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT9.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT10.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT11.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT12.V DC.UV.MPPT_significant
# Inv.DC.I.MPTT1.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT2.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT3.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT4.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT5.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT6.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT7.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT8.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT9.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT10.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT11.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT12.A DC.IA.MPPT_significant
# Inv.DC.R.Ohm None
# ==================================================
# 25: MID: MNTR|c532be0e-d610-40e6-9a2f-fb4c2ae646eb, pv_size: 66560
# Gen.W
# metrics_name_list: ['Gen.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.I.Ph1.A', 'Inv.DC.U.MPTT1.V']
# ==================================================
# 26: MID: MNTR|6701590, pv_size: 99900
# Gen.W
# Inv.DC.P.MPTT1.W
# Inv.DC.P.MPTT2.W
# Inv.DC.P.MPTT3.W
# Inv.DC.P.MPTT4.W
# Inv.DC.P.MPTT5.W
# Inv.DC.P.MPTT6.W
# Inv.DC.P.MPTT7.W
# Inv.DC.P.MPTT8.W
# Inv.DC.P.MPTT9.W
# Inv.DC.P.MPTT10.W
# Inv.DC.P.MPTT11.W
# Inv.DC.P.MPTT12.W
# metrics_name_list: ['Gen.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.U.Ph2.V', 'Inv.AC.U.Ph3.V', 'Inv.AC.I.Ph1.A', 'Inv.AC.I.Ph2.A', 'Inv.AC.I.Ph3.A', 'Inv.DC.P.MPTT1.W', 'Inv.DC.P.MPTT2.W', 'Inv.DC.P.MPTT3.W', 'Inv.DC.P.MPTT4.W', 'Inv.DC.P.MPTT5.W', 'Inv.DC.P.MPTT6.W', 'Inv.DC.P.MPTT7.W', 'Inv.DC.P.MPTT8.W', 'Inv.DC.P.MPTT9.W', 'Inv.DC.P.MPTT10.W', 'Inv.DC.P.MPTT11.W', 'Inv.DC.P.MPTT12.W', 'Inv.DC.U.MPTT1.V', 'Inv.DC.U.MPTT2.V', 'Inv.DC.U.MPTT3.V', 'Inv.DC.U.MPTT4.V', 'Inv.DC.U.MPTT5.V', 'Inv.DC.U.MPTT6.V', 'Inv.DC.U.MPTT7.V', 'Inv.DC.U.MPTT8.V', 'Inv.DC.U.MPTT9.V', 'Inv.DC.U.MPTT10.V', 'Inv.DC.U.MPTT11.V', 'Inv.DC.U.MPTT12.V', 'Inv.DC.I.MPTT1.A', 'Inv.DC.I.MPTT2.A', 'Inv.DC.I.MPTT3.A', 'Inv.DC.I.MPTT4.A', 'Inv.DC.I.MPTT5.A', 'Inv.DC.I.MPTT6.A', 'Inv.DC.I.MPTT7.A', 'Inv.DC.I.MPTT8.A', 'Inv.DC.I.MPTT9.A', 'Inv.DC.I.MPTT10.A', 'Inv.DC.I.MPTT11.A', 'Inv.DC.I.MPTT12.A', 'Inv.DC.R.Ohm']
# significant days: 208
# Gen.W None
# Inv.AC.U.Ph1.V AC.UV.Ph_significant
# Inv.AC.U.Ph2.V AC.UV.Ph_significant
# Inv.AC.U.Ph3.V AC.UV.Ph_significant
# Inv.AC.I.Ph1.A AC.IA.Ph_significant
# Inv.AC.I.Ph2.A AC.IA.Ph_significant
# Inv.AC.I.Ph3.A AC.IA.Ph_significant
# Inv.DC.P.MPTT1.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT2.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT3.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT4.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT5.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT6.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT7.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT8.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT9.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT10.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT11.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT12.W DC.PW.MPPT_significant
# Inv.DC.U.MPTT1.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT2.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT3.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT4.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT5.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT6.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT7.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT8.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT9.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT10.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT11.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT12.V DC.UV.MPPT_significant
# Inv.DC.I.MPTT1.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT2.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT3.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT4.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT5.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT6.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT7.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT8.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT9.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT10.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT11.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT12.A DC.IA.MPPT_significant
# Inv.DC.R.Ohm None
# more than 20 days are experienced significant difference
# Gen.W None
# Inv.AC.U.Ph1.V AC.UV.Ph_significant
# Inv.AC.U.Ph2.V AC.UV.Ph_significant
# Inv.AC.U.Ph3.V AC.UV.Ph_significant
# Inv.AC.I.Ph1.A AC.IA.Ph_significant
# Inv.AC.I.Ph2.A AC.IA.Ph_significant
# Inv.AC.I.Ph3.A AC.IA.Ph_significant
# Inv.DC.P.MPTT1.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT2.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT3.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT4.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT5.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT6.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT7.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT8.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT9.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT10.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT11.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT12.W DC.PW.MPPT_significant
# Inv.DC.U.MPTT1.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT2.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT3.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT4.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT5.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT6.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT7.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT8.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT9.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT10.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT11.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT12.V DC.UV.MPPT_significant
# Inv.DC.I.MPTT1.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT2.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT3.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT4.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT5.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT6.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT7.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT8.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT9.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT10.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT11.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT12.A DC.IA.MPPT_significant
# Inv.DC.R.Ohm None
# ==================================================
# 27: MID: MNTR|d11d80cf-b6c1-477d-91a2-b82f17b340df, pv_size: 27770
# Gen.W
# metrics_name_list: ['Gen.W']
# ==================================================
# 28: MID: MNTR|1871864, pv_size: 27770
# Gen.W
# Inv.AC.P.Ph1.W
# Inv.AC.P.Ph2.W
# Inv.AC.P.Ph3.W
# Inv.DC.P.MPTT1.W
# Inv.DC.P.MPTT2.W
# metrics_name_list: ['Gen.W', 'Inv.AC.P.Ph1.W', 'Inv.AC.P.Ph2.W', 'Inv.AC.P.Ph3.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.U.Ph2.V', 'Inv.AC.U.Ph3.V', 'Inv.AC.I.Ph1.A', 'Inv.AC.I.Ph2.A', 'Inv.AC.I.Ph3.A', 'Inv.DC.P.MPTT1.W', 'Inv.DC.P.MPTT2.W', 'Inv.DC.U.MPTT1.V', 'Inv.DC.U.MPTT2.V', 'Inv.DC.I.MPTT1.A', 'Inv.DC.I.MPTT2.A', 'Inv.DC.R.Ohm']
# ==================================================
# 29: MID: MNTR|51b4019b-f970-4b66-bf4a-d7ab81b1b5ca, pv_size: 27770
# Gen.W
# metrics_name_list: ['Gen.W']
# ==================================================
# 30: MID: MNTR|6315868, pv_size: 19240
# Gen.W
# Inv.AC.P.Ph1.W
# Inv.AC.P.Ph2.W
# Inv.AC.P.Ph3.W
# Inv.DC.P.MPTT1.W
# Inv.DC.P.MPTT2.W
# metrics_name_list: ['Gen.W', 'Inv.AC.P.Ph1.W', 'Inv.AC.P.Ph2.W', 'Inv.AC.P.Ph3.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.U.Ph2.V', 'Inv.AC.U.Ph3.V', 'Inv.AC.I.Ph1.A', 'Inv.AC.I.Ph2.A', 'Inv.AC.I.Ph3.A', 'Inv.DC.P.MPTT1.W', 'Inv.DC.P.MPTT2.W', 'Inv.DC.U.MPTT1.V', 'Inv.DC.U.MPTT2.V', 'Inv.DC.I.MPTT1.A', 'Inv.DC.I.MPTT2.A', 'Inv.DC.R.Ohm']
# significant days: 90
# Gen.W None
# Inv.AC.P.Ph1.W AC.PW.Ph_significant
# Inv.AC.P.Ph2.W AC.PW.Ph_significant
# Inv.AC.P.Ph3.W AC.PW.Ph_significant
# Inv.AC.U.Ph1.V AC.UV.Ph_significant
# Inv.AC.U.Ph2.V AC.UV.Ph_significant
# Inv.AC.U.Ph3.V AC.UV.Ph_significant
# Inv.AC.I.Ph1.A AC.IA.Ph_significant
# Inv.AC.I.Ph2.A AC.IA.Ph_significant
# Inv.AC.I.Ph3.A AC.IA.Ph_significant
# Inv.DC.P.MPTT1.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT2.W DC.PW.MPPT_significant
# Inv.DC.U.MPTT1.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT2.V DC.UV.MPPT_significant
# Inv.DC.I.MPTT1.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT2.A DC.IA.MPPT_significant
# Inv.DC.R.Ohm None
# more than 20 days are experienced significant difference
# Gen.W None
# Inv.AC.P.Ph1.W AC.PW.Ph_significant
# Inv.AC.P.Ph2.W AC.PW.Ph_significant
# Inv.AC.P.Ph3.W AC.PW.Ph_significant
# Inv.AC.U.Ph1.V AC.UV.Ph_significant
# Inv.AC.U.Ph2.V AC.UV.Ph_significant
# Inv.AC.U.Ph3.V AC.UV.Ph_significant
# Inv.AC.I.Ph1.A AC.IA.Ph_significant
# Inv.AC.I.Ph2.A AC.IA.Ph_significant
# Inv.AC.I.Ph3.A AC.IA.Ph_significant
# Inv.DC.P.MPTT1.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT2.W DC.PW.MPPT_significant
# Inv.DC.U.MPTT1.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT2.V DC.UV.MPPT_significant
# Inv.DC.I.MPTT1.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT2.A DC.IA.MPPT_significant
# Inv.DC.R.Ohm None
# ==================================================
# 31: MID: MNTR|0eafea0d-078d-4d2b-b905-ca5f1a7aed5a, pv_size: 61220
# Gen.W
# metrics_name_list: ['Gen.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.I.Ph1.A', 'Inv.DC.U.MPTT1.V', 'Inv.DC.I.MPTT1.A']
# ==================================================
# 32: MID: MNTR|4828249, pv_size: 22765
# Gen.W
# Inv.AC.P.Ph1.W
# Inv.AC.P.Ph2.W
# Inv.AC.P.Ph3.W
# Inv.DC.P.MPTT1.W
# Inv.DC.P.MPTT2.W
# metrics_name_list: ['Gen.W', 'Inv.AC.P.Ph1.W', 'Inv.AC.P.Ph2.W', 'Inv.AC.P.Ph3.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.U.Ph2.V', 'Inv.AC.U.Ph3.V', 'Inv.AC.I.Ph1.A', 'Inv.AC.I.Ph2.A', 'Inv.AC.I.Ph3.A', 'Inv.DC.P.MPTT1.W', 'Inv.DC.P.MPTT2.W', 'Inv.DC.U.MPTT1.V', 'Inv.DC.U.MPTT2.V', 'Inv.DC.I.MPTT1.A', 'Inv.DC.I.MPTT2.A', 'Inv.DC.R.Ohm']
# significant days: 19
# Gen.W None
# Inv.AC.P.Ph1.W AC.PW.Ph_significant
# Inv.AC.P.Ph2.W AC.PW.Ph_significant
# Inv.AC.P.Ph3.W AC.PW.Ph_significant
# Inv.AC.U.Ph1.V AC.UV.Ph_significant
# Inv.AC.U.Ph2.V AC.UV.Ph_significant
# Inv.AC.U.Ph3.V AC.UV.Ph_significant
# Inv.AC.I.Ph1.A AC.IA.Ph_significant
# Inv.AC.I.Ph2.A AC.IA.Ph_significant
# Inv.AC.I.Ph3.A AC.IA.Ph_significant
# Inv.DC.P.MPTT1.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT2.W DC.PW.MPPT_significant
# Inv.DC.U.MPTT1.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT2.V DC.UV.MPPT_significant
# Inv.DC.I.MPTT1.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT2.A DC.IA.MPPT_significant
# Inv.DC.R.Ohm None
# ==================================================
# 33: MID: MNTR|3515936, pv_size: 16630
# Gen.W
# Inv.AC.P.Ph1.W
# Inv.AC.P.Ph2.W
# Inv.AC.P.Ph3.W
# metrics_name_list: ['Gen.W', 'Inv.AC.P.Ph1.W', 'Inv.AC.P.Ph2.W', 'Inv.AC.P.Ph3.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.U.Ph2.V', 'Inv.AC.U.Ph3.V', 'Inv.AC.I.Ph1.A', 'Inv.AC.I.Ph2.A', 'Inv.AC.I.Ph3.A']
# ==================================================
# 34: MID: MNTR|1efa91ef-53bf-40be-9438-7258330ed391, pv_size: 61220
# Gen.W
# metrics_name_list: ['Gen.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.I.Ph1.A']
# ==================================================
# 35: MID: MNTR|75aa470a-0cda-4abe-8f31-d4a623b91f31, pv_size: 47150
# Gen.W
# Inv.DC.P.MPTT1.W
# Inv.DC.P.MPTT2.W
# Inv.DC.P.MPTT3.W
# Inv.DC.P.MPTT4.W
# Inv.DC.P.MPTT5.W
# Inv.DC.P.MPTT6.W
# metrics_name_list: ['Gen.W', 'Inv.DC.P.MPTT1.W', 'Inv.DC.P.MPTT2.W', 'Inv.DC.P.MPTT3.W', 'Inv.DC.P.MPTT4.W', 'Inv.DC.P.MPTT5.W', 'Inv.DC.P.MPTT6.W']
# significant days: 5
# Gen.W None
# Inv.DC.P.MPTT1.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT2.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT3.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT4.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT5.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT6.W DC.PW.MPPT_significant
# ==================================================
# 36: MID: MNTR|3987793, pv_size: 28807
# Gen.W
# Inv.AC.P.Ph1.W
# Inv.AC.P.Ph2.W
# Inv.AC.P.Ph3.W
# Inv.DC.P.MPTT1.W
# Inv.DC.P.MPTT2.W
# metrics_name_list: ['Gen.W', 'Inv.AC.P.Ph1.W', 'Inv.AC.P.Ph2.W', 'Inv.AC.P.Ph3.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.U.Ph2.V', 'Inv.AC.U.Ph3.V', 'Inv.AC.I.Ph1.A', 'Inv.AC.I.Ph2.A', 'Inv.AC.I.Ph3.A', 'Inv.DC.P.MPTT1.W', 'Inv.DC.P.MPTT2.W', 'Inv.DC.U.MPTT1.V', 'Inv.DC.U.MPTT2.V', 'Inv.DC.I.MPTT1.A', 'Inv.DC.I.MPTT2.A', 'Inv.DC.R.Ohm']
# significant days: 31
# Gen.W None
# Inv.AC.P.Ph1.W AC.PW.Ph_significant
# Inv.AC.P.Ph2.W AC.PW.Ph_significant
# Inv.AC.P.Ph3.W AC.PW.Ph_significant
# Inv.AC.U.Ph1.V AC.UV.Ph_significant
# Inv.AC.U.Ph2.V AC.UV.Ph_significant
# Inv.AC.U.Ph3.V AC.UV.Ph_significant
# Inv.AC.I.Ph1.A AC.IA.Ph_significant
# Inv.AC.I.Ph2.A AC.IA.Ph_significant
# Inv.AC.I.Ph3.A AC.IA.Ph_significant
# Inv.DC.P.MPTT1.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT2.W DC.PW.MPPT_significant
# Inv.DC.U.MPTT1.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT2.V DC.UV.MPPT_significant
# Inv.DC.I.MPTT1.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT2.A DC.IA.MPPT_significant
# Inv.DC.R.Ohm None
# more than 20 days are experienced significant difference
# Gen.W None
# Inv.AC.P.Ph1.W AC.PW.Ph_significant
# Inv.AC.P.Ph2.W AC.PW.Ph_significant
# Inv.AC.P.Ph3.W AC.PW.Ph_significant
# Inv.AC.U.Ph1.V AC.UV.Ph_significant
# Inv.AC.U.Ph2.V AC.UV.Ph_significant
# Inv.AC.U.Ph3.V AC.UV.Ph_significant
# Inv.AC.I.Ph1.A AC.IA.Ph_significant
# Inv.AC.I.Ph2.A AC.IA.Ph_significant
# Inv.AC.I.Ph3.A AC.IA.Ph_significant
# Inv.DC.P.MPTT1.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT2.W DC.PW.MPPT_significant
# Inv.DC.U.MPTT1.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT2.V DC.UV.MPPT_significant
# Inv.DC.I.MPTT1.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT2.A DC.IA.MPPT_significant
# Inv.DC.R.Ohm None
# ==================================================
# 37: MID: MNTR|5332900, pv_size: 16630
# Gen.W
# Inv.AC.P.Ph1.W
# Inv.AC.P.Ph2.W
# Inv.AC.P.Ph3.W
# Inv.DC.P.MPTT1.W
# Inv.DC.P.MPTT2.W
# metrics_name_list: ['Gen.W', 'Inv.AC.P.Ph1.W', 'Inv.AC.P.Ph2.W', 'Inv.AC.P.Ph3.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.U.Ph2.V', 'Inv.AC.U.Ph3.V', 'Inv.AC.I.Ph1.A', 'Inv.AC.I.Ph2.A', 'Inv.AC.I.Ph3.A', 'Inv.DC.P.MPTT1.W', 'Inv.DC.P.MPTT2.W', 'Inv.DC.U.MPTT1.V', 'Inv.DC.U.MPTT2.V', 'Inv.DC.I.MPTT1.A', 'Inv.DC.I.MPTT2.A', 'Inv.DC.R.Ohm']
# ==================================================
# 38: MID: MNTR|1509100, pv_size: 27770
# Gen.W
# Inv.AC.P.Ph1.W
# Inv.AC.P.Ph2.W
# Inv.AC.P.Ph3.W
# Inv.DC.P.MPTT1.W
# Inv.DC.P.MPTT2.W
# metrics_name_list: ['Gen.W', 'Inv.AC.P.Ph1.W', 'Inv.AC.P.Ph2.W', 'Inv.AC.P.Ph3.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.U.Ph2.V', 'Inv.AC.U.Ph3.V', 'Inv.AC.I.Ph1.A', 'Inv.AC.I.Ph2.A', 'Inv.AC.I.Ph3.A', 'Inv.DC.P.MPTT1.W', 'Inv.DC.P.MPTT2.W', 'Inv.DC.U.MPTT1.V', 'Inv.DC.U.MPTT2.V', 'Inv.DC.I.MPTT1.A', 'Inv.DC.I.MPTT2.A', 'Inv.DC.R.Ohm']
# ==================================================
# 39: MID: MNTR|2204239, pv_size: 27770
# Gen.W
# Inv.AC.P.Ph1.W
# Inv.AC.P.Ph2.W
# Inv.AC.P.Ph3.W
# Inv.DC.P.MPTT1.W
# Inv.DC.P.MPTT2.W
# metrics_name_list: ['Gen.W', 'Inv.AC.P.Ph1.W', 'Inv.AC.P.Ph2.W', 'Inv.AC.P.Ph3.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.U.Ph2.V', 'Inv.AC.U.Ph3.V', 'Inv.AC.I.Ph1.A', 'Inv.AC.I.Ph2.A', 'Inv.AC.I.Ph3.A', 'Inv.DC.P.MPTT1.W', 'Inv.DC.P.MPTT2.W', 'Inv.DC.U.MPTT1.V', 'Inv.DC.U.MPTT2.V', 'Inv.DC.I.MPTT1.A', 'Inv.DC.I.MPTT2.A', 'Inv.DC.R.Ohm']
# ==================================================
# 40: MID: MNTR|1483750, pv_size: 27770
# Gen.W
# Inv.AC.P.Ph1.W
# Inv.AC.P.Ph2.W
# Inv.AC.P.Ph3.W
# Inv.DC.P.MPTT1.W
# Inv.DC.P.MPTT2.W
# metrics_name_list: ['Gen.W', 'Inv.AC.P.Ph1.W', 'Inv.AC.P.Ph2.W', 'Inv.AC.P.Ph3.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.U.Ph2.V', 'Inv.AC.U.Ph3.V', 'Inv.AC.I.Ph1.A', 'Inv.AC.I.Ph2.A', 'Inv.AC.I.Ph3.A', 'Inv.DC.P.MPTT1.W', 'Inv.DC.P.MPTT2.W', 'Inv.DC.U.MPTT1.V', 'Inv.DC.U.MPTT2.V', 'Inv.DC.I.MPTT1.A', 'Inv.DC.I.MPTT2.A', 'Inv.DC.R.Ohm']
# ==================================================
# 41: MID: MNTR|5541098, pv_size: 30200
# Gen.W
# Inv.AC.P.Ph1.W
# Inv.AC.P.Ph2.W
# Inv.AC.P.Ph3.W
# Inv.DC.P.MPTT1.W
# Inv.DC.P.MPTT2.W
# metrics_name_list: ['Gen.W', 'Inv.AC.P.Ph1.W', 'Inv.AC.P.Ph2.W', 'Inv.AC.P.Ph3.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.U.Ph2.V', 'Inv.AC.U.Ph3.V', 'Inv.AC.I.Ph1.A', 'Inv.AC.I.Ph2.A', 'Inv.AC.I.Ph3.A', 'Inv.DC.P.MPTT1.W', 'Inv.DC.P.MPTT2.W', 'Inv.DC.U.MPTT1.V', 'Inv.DC.U.MPTT2.V', 'Inv.DC.I.MPTT1.A', 'Inv.DC.I.MPTT2.A', 'Inv.DC.R.Ohm']
# significant days: 43
# Gen.W None
# Inv.AC.P.Ph1.W AC.PW.Ph_significant
# Inv.AC.P.Ph2.W AC.PW.Ph_significant
# Inv.AC.P.Ph3.W AC.PW.Ph_significant
# Inv.AC.U.Ph1.V AC.UV.Ph_significant
# Inv.AC.U.Ph2.V AC.UV.Ph_significant
# Inv.AC.U.Ph3.V AC.UV.Ph_significant
# Inv.AC.I.Ph1.A AC.IA.Ph_significant
# Inv.AC.I.Ph2.A AC.IA.Ph_significant
# Inv.AC.I.Ph3.A AC.IA.Ph_significant
# Inv.DC.P.MPTT1.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT2.W DC.PW.MPPT_significant
# Inv.DC.U.MPTT1.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT2.V DC.UV.MPPT_significant
# Inv.DC.I.MPTT1.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT2.A DC.IA.MPPT_significant
# Inv.DC.R.Ohm None
# more than 20 days are experienced significant difference
# Gen.W None
# Inv.AC.P.Ph1.W AC.PW.Ph_significant
# Inv.AC.P.Ph2.W AC.PW.Ph_significant
# Inv.AC.P.Ph3.W AC.PW.Ph_significant
# Inv.AC.U.Ph1.V AC.UV.Ph_significant
# Inv.AC.U.Ph2.V AC.UV.Ph_significant
# Inv.AC.U.Ph3.V AC.UV.Ph_significant
# Inv.AC.I.Ph1.A AC.IA.Ph_significant
# Inv.AC.I.Ph2.A AC.IA.Ph_significant
# Inv.AC.I.Ph3.A AC.IA.Ph_significant
# Inv.DC.P.MPTT1.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT2.W DC.PW.MPPT_significant
# Inv.DC.U.MPTT1.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT2.V DC.UV.MPPT_significant
# Inv.DC.I.MPTT1.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT2.A DC.IA.MPPT_significant
# Inv.DC.R.Ohm None
# ==================================================
# 42: MID: MNTR|1036311, pv_size: 27670
# Gen.W
# Inv.AC.P.Ph1.W
# Inv.AC.P.Ph2.W
# Inv.AC.P.Ph3.W
# Inv.DC.P.MPTT1.W
# Inv.DC.P.MPTT2.W
# metrics_name_list: ['Gen.W', 'Inv.AC.P.Ph1.W', 'Inv.AC.P.Ph2.W', 'Inv.AC.P.Ph3.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.U.Ph2.V', 'Inv.AC.U.Ph3.V', 'Inv.AC.I.Ph1.A', 'Inv.AC.I.Ph2.A', 'Inv.AC.I.Ph3.A', 'Inv.DC.P.MPTT1.W', 'Inv.DC.P.MPTT2.W', 'Inv.DC.U.MPTT1.V', 'Inv.DC.U.MPTT2.V', 'Inv.DC.I.MPTT1.A', 'Inv.DC.I.MPTT2.A', 'Inv.DC.R.Ohm']
# ==================================================
# 43: MID: MNTR|77345003-0d28-46bc-ac0f-41332489c434, pv_size: 71870
# Gen.W
# metrics_name_list: ['Gen.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.I.Ph1.A', 'Inv.DC.U.MPTT1.V']
# ==================================================
# 44: MID: MNTR|029c55a1-ee99-4e5a-b02a-2df8d5a81c51, pv_size: 27770
# Gen.W
# metrics_name_list: ['Gen.W']
# ==================================================
# 45: MID: MNTR|57a90d09-b3ce-449e-a343-4de7034d2e3b, pv_size: 75830
# Gen.W
# metrics_name_list: ['Gen.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.I.Ph1.A', 'Inv.DC.U.MPTT1.V']
# ==================================================
# 46: MID: MNTR|6308609, pv_size: 27750
# Gen.W
# Inv.AC.P.Ph1.W
# Inv.AC.P.Ph2.W
# Inv.AC.P.Ph3.W
# Inv.DC.P.MPTT1.W
# Inv.DC.P.MPTT2.W
# metrics_name_list: ['Gen.W', 'Inv.AC.P.Ph1.W', 'Inv.AC.P.Ph2.W', 'Inv.AC.P.Ph3.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.U.Ph2.V', 'Inv.AC.U.Ph3.V', 'Inv.AC.I.Ph1.A', 'Inv.AC.I.Ph2.A', 'Inv.AC.I.Ph3.A', 'Inv.DC.P.MPTT1.W', 'Inv.DC.P.MPTT2.W', 'Inv.DC.U.MPTT1.V', 'Inv.DC.U.MPTT2.V', 'Inv.DC.I.MPTT1.A', 'Inv.DC.I.MPTT2.A', 'Inv.DC.R.Ohm']
# ==================================================
# 47: MID: MNTR|2721556, pv_size: 24990
# Gen.W
# Inv.AC.P.Ph1.W
# Inv.AC.P.Ph2.W
# Inv.AC.P.Ph3.W
# metrics_name_list: ['Gen.W', 'Inv.AC.P.Ph1.W', 'Inv.AC.P.Ph2.W', 'Inv.AC.P.Ph3.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.U.Ph2.V', 'Inv.AC.U.Ph3.V', 'Inv.AC.I.Ph1.A', 'Inv.AC.I.Ph2.A', 'Inv.AC.I.Ph3.A']
# ==================================================
# 48: MID: MNTR|8ec6b238-7bef-47c9-992e-8b498b3a9f59, pv_size: 61220
# Gen.W
# metrics_name_list: ['Gen.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.I.Ph1.A', 'Inv.DC.U.MPTT1.V']
# ==================================================
# 49: MID: MNTR|6145075, pv_size: 27770
# Gen.W
# Inv.AC.P.Ph1.W
# Inv.AC.P.Ph2.W
# Inv.AC.P.Ph3.W
# Inv.DC.P.MPTT1.W
# Inv.DC.P.MPTT2.W
# metrics_name_list: ['Gen.W', 'Inv.AC.P.Ph1.W', 'Inv.AC.P.Ph2.W', 'Inv.AC.P.Ph3.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.U.Ph2.V', 'Inv.AC.U.Ph3.V', 'Inv.AC.I.Ph1.A', 'Inv.AC.I.Ph2.A', 'Inv.AC.I.Ph3.A', 'Inv.DC.P.MPTT1.W', 'Inv.DC.P.MPTT2.W', 'Inv.DC.U.MPTT1.V', 'Inv.DC.U.MPTT2.V', 'Inv.DC.I.MPTT1.A', 'Inv.DC.I.MPTT2.A', 'Inv.DC.R.Ohm']
# significant days: 1
# Gen.W None
# Inv.AC.P.Ph1.W AC.PW.Ph_significant
# Inv.AC.P.Ph2.W AC.PW.Ph_significant
# Inv.AC.P.Ph3.W AC.PW.Ph_significant
# Inv.AC.U.Ph1.V AC.UV.Ph_significant
# Inv.AC.U.Ph2.V AC.UV.Ph_significant
# Inv.AC.U.Ph3.V AC.UV.Ph_significant
# Inv.AC.I.Ph1.A AC.IA.Ph_significant
# Inv.AC.I.Ph2.A AC.IA.Ph_significant
# Inv.AC.I.Ph3.A AC.IA.Ph_significant
# Inv.DC.P.MPTT1.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT2.W DC.PW.MPPT_significant
# Inv.DC.U.MPTT1.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT2.V DC.UV.MPPT_significant
# Inv.DC.I.MPTT1.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT2.A DC.IA.MPPT_significant
# Inv.DC.R.Ohm None
# ==================================================
# 50: MID: MNTR|6004047, pv_size: 27710
# Gen.W
# Inv.AC.P.Ph1.W
# Inv.AC.P.Ph2.W
# Inv.AC.P.Ph3.W
# Inv.DC.P.MPTT1.W
# Inv.DC.P.MPTT2.W
# metrics_name_list: ['Gen.W', 'Inv.AC.P.Ph1.W', 'Inv.AC.P.Ph2.W', 'Inv.AC.P.Ph3.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.U.Ph2.V', 'Inv.AC.U.Ph3.V', 'Inv.AC.I.Ph1.A', 'Inv.AC.I.Ph2.A', 'Inv.AC.I.Ph3.A', 'Inv.DC.P.MPTT1.W', 'Inv.DC.P.MPTT2.W', 'Inv.DC.U.MPTT1.V', 'Inv.DC.U.MPTT2.V', 'Inv.DC.I.MPTT1.A', 'Inv.DC.I.MPTT2.A', 'Inv.DC.R.Ohm']
# ==================================================
# 51: MID: MNTR|4404512, pv_size: 22890
# Gen.W
# Inv.AC.P.Ph1.W
# Inv.AC.P.Ph2.W
# Inv.AC.P.Ph3.W
# Inv.DC.P.MPTT1.W
# Inv.DC.P.MPTT2.W
# metrics_name_list: ['Gen.W', 'Inv.AC.P.Ph1.W', 'Inv.AC.P.Ph2.W', 'Inv.AC.P.Ph3.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.U.Ph2.V', 'Inv.AC.U.Ph3.V', 'Inv.AC.I.Ph1.A', 'Inv.AC.I.Ph2.A', 'Inv.AC.I.Ph3.A', 'Inv.DC.P.MPTT1.W', 'Inv.DC.P.MPTT2.W', 'Inv.DC.U.MPTT1.V', 'Inv.DC.U.MPTT2.V', 'Inv.DC.I.MPTT1.A', 'Inv.DC.I.MPTT2.A', 'Inv.DC.R.Ohm']
# significant days: 54
# Gen.W None
# Inv.AC.P.Ph1.W AC.PW.Ph_significant
# Inv.AC.P.Ph2.W AC.PW.Ph_significant
# Inv.AC.P.Ph3.W AC.PW.Ph_significant
# Inv.AC.U.Ph1.V AC.UV.Ph_significant
# Inv.AC.U.Ph2.V AC.UV.Ph_significant
# Inv.AC.U.Ph3.V AC.UV.Ph_significant
# Inv.AC.I.Ph1.A AC.IA.Ph_significant
# Inv.AC.I.Ph2.A AC.IA.Ph_significant
# Inv.AC.I.Ph3.A AC.IA.Ph_significant
# Inv.DC.P.MPTT1.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT2.W DC.PW.MPPT_significant
# Inv.DC.U.MPTT1.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT2.V DC.UV.MPPT_significant
# Inv.DC.I.MPTT1.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT2.A DC.IA.MPPT_significant
# Inv.DC.R.Ohm None
# more than 20 days are experienced significant difference
# ==================================================
# 52: MID: MNTR|2157467, pv_size: 27770
# Gen.W
# Inv.AC.P.Ph1.W
# Inv.AC.P.Ph2.W
# Inv.AC.P.Ph3.W
# Inv.DC.P.MPTT1.W
# Inv.DC.P.MPTT2.W
# metrics_name_list: ['Gen.W', 'Inv.AC.P.Ph1.W', 'Inv.AC.P.Ph2.W', 'Inv.AC.P.Ph3.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.U.Ph2.V', 'Inv.AC.U.Ph3.V', 'Inv.AC.I.Ph1.A', 'Inv.AC.I.Ph2.A', 'Inv.AC.I.Ph3.A', 'Inv.DC.P.MPTT1.W', 'Inv.DC.P.MPTT2.W', 'Inv.DC.U.MPTT1.V', 'Inv.DC.U.MPTT2.V', 'Inv.DC.I.MPTT1.A', 'Inv.DC.I.MPTT2.A', 'Inv.DC.R.Ohm']
# ==================================================
# 53: MID: MNTR|6039756, pv_size: 21707
# Gen.W
# Inv.AC.P.Ph1.W
# Inv.AC.P.Ph2.W
# Inv.AC.P.Ph3.W
# Inv.DC.P.MPTT1.W
# Inv.DC.P.MPTT2.W
# metrics_name_list: ['Gen.W', 'Inv.AC.P.Ph1.W', 'Inv.AC.P.Ph2.W', 'Inv.AC.P.Ph3.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.U.Ph2.V', 'Inv.AC.U.Ph3.V', 'Inv.AC.I.Ph1.A', 'Inv.AC.I.Ph2.A', 'Inv.AC.I.Ph3.A', 'Inv.DC.P.MPTT1.W', 'Inv.DC.P.MPTT2.W', 'Inv.DC.U.MPTT1.V', 'Inv.DC.U.MPTT2.V', 'Inv.DC.I.MPTT1.A', 'Inv.DC.I.MPTT2.A', 'Inv.DC.R.Ohm']
# significant days: 25
# Gen.W None
# Inv.AC.P.Ph1.W AC.PW.Ph_significant
# Inv.AC.P.Ph2.W AC.PW.Ph_significant
# Inv.AC.P.Ph3.W AC.PW.Ph_significant
# Inv.AC.U.Ph1.V AC.UV.Ph_significant
# Inv.AC.U.Ph2.V AC.UV.Ph_significant
# Inv.AC.U.Ph3.V AC.UV.Ph_significant
# Inv.AC.I.Ph1.A AC.IA.Ph_significant
# Inv.AC.I.Ph2.A AC.IA.Ph_significant
# Inv.AC.I.Ph3.A AC.IA.Ph_significant
# Inv.DC.P.MPTT1.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT2.W DC.PW.MPPT_significant
# Inv.DC.U.MPTT1.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT2.V DC.UV.MPPT_significant
# Inv.DC.I.MPTT1.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT2.A DC.IA.MPPT_significant
# Inv.DC.R.Ohm None
# more than 20 days are experienced significant difference
# Gen.W None
# Inv.AC.P.Ph1.W AC.PW.Ph_significant
# Inv.AC.P.Ph2.W AC.PW.Ph_significant
# Inv.AC.P.Ph3.W AC.PW.Ph_significant
# Inv.AC.U.Ph1.V AC.UV.Ph_significant
# Inv.AC.U.Ph2.V AC.UV.Ph_significant
# Inv.AC.U.Ph3.V AC.UV.Ph_significant
# Inv.AC.I.Ph1.A AC.IA.Ph_significant
# Inv.AC.I.Ph2.A AC.IA.Ph_significant
# Inv.AC.I.Ph3.A AC.IA.Ph_significant
# Inv.DC.P.MPTT1.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT2.W DC.PW.MPPT_significant
# Inv.DC.U.MPTT1.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT2.V DC.UV.MPPT_significant
# Inv.DC.I.MPTT1.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT2.A DC.IA.MPPT_significant
# Inv.DC.R.Ohm None
# ==================================================
# 54: MID: MNTR|6314066, pv_size: 16660
# Gen.W
# Inv.AC.P.Ph1.W
# Inv.AC.P.Ph2.W
# Inv.AC.P.Ph3.W
# Inv.DC.P.MPTT1.W
# Inv.DC.P.MPTT2.W
# metrics_name_list: ['Gen.W', 'Inv.AC.P.Ph1.W', 'Inv.AC.P.Ph2.W', 'Inv.AC.P.Ph3.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.U.Ph2.V', 'Inv.AC.U.Ph3.V', 'Inv.AC.I.Ph1.A', 'Inv.AC.I.Ph2.A', 'Inv.AC.I.Ph3.A', 'Inv.DC.P.MPTT1.W', 'Inv.DC.P.MPTT2.W', 'Inv.DC.U.MPTT1.V', 'Inv.DC.U.MPTT2.V', 'Inv.DC.I.MPTT1.A', 'Inv.DC.I.MPTT2.A', 'Inv.DC.R.Ohm']
# ==================================================
# 55: MID: MNTR|2721555, pv_size: 24990
# Gen.W
# Inv.AC.P.Ph1.W
# Inv.AC.P.Ph2.W
# Inv.AC.P.Ph3.W
# metrics_name_list: ['Gen.W', 'Inv.AC.P.Ph1.W', 'Inv.AC.P.Ph2.W', 'Inv.AC.P.Ph3.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.U.Ph2.V', 'Inv.AC.U.Ph3.V', 'Inv.AC.I.Ph1.A', 'Inv.AC.I.Ph2.A', 'Inv.AC.I.Ph3.A']
# ==================================================
# 56: MID: MNTR|5479147, pv_size: 16660
# Gen.W
# Inv.AC.P.Ph1.W
# Inv.AC.P.Ph2.W
# Inv.AC.P.Ph3.W
# Inv.DC.P.MPTT1.W
# Inv.DC.P.MPTT2.W
# metrics_name_list: ['Gen.W', 'Inv.AC.P.Ph1.W', 'Inv.AC.P.Ph2.W', 'Inv.AC.P.Ph3.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.U.Ph2.V', 'Inv.AC.U.Ph3.V', 'Inv.AC.I.Ph1.A', 'Inv.AC.I.Ph2.A', 'Inv.AC.I.Ph3.A', 'Inv.DC.P.MPTT1.W', 'Inv.DC.P.MPTT2.W', 'Inv.DC.U.MPTT1.V', 'Inv.DC.U.MPTT2.V', 'Inv.DC.I.MPTT1.A', 'Inv.DC.I.MPTT2.A', 'Inv.DC.R.Ohm']
# significant days: 4
# Gen.W None
# Inv.AC.P.Ph1.W AC.PW.Ph_significant
# Inv.AC.P.Ph2.W AC.PW.Ph_significant
# Inv.AC.P.Ph3.W AC.PW.Ph_significant
# Inv.AC.U.Ph1.V AC.UV.Ph_significant
# Inv.AC.U.Ph2.V AC.UV.Ph_significant
# Inv.AC.U.Ph3.V AC.UV.Ph_significant
# Inv.AC.I.Ph1.A AC.IA.Ph_significant
# Inv.AC.I.Ph2.A AC.IA.Ph_significant
# Inv.AC.I.Ph3.A AC.IA.Ph_significant
# Inv.DC.P.MPTT1.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT2.W DC.PW.MPPT_significant
# Inv.DC.U.MPTT1.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT2.V DC.UV.MPPT_significant
# Inv.DC.I.MPTT1.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT2.A DC.IA.MPPT_significant
# Inv.DC.R.Ohm None
# ==================================================
# 57: MID: MNTR|2401361, pv_size: 16660
# Gen.W
# Inv.AC.P.Ph1.W
# Inv.AC.P.Ph2.W
# Inv.AC.P.Ph3.W
# Inv.DC.P.MPTT1.W
# Inv.DC.P.MPTT2.W
# metrics_name_list: ['Gen.W', 'Inv.AC.P.Ph1.W', 'Inv.AC.P.Ph2.W', 'Inv.AC.P.Ph3.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.U.Ph2.V', 'Inv.AC.U.Ph3.V', 'Inv.AC.I.Ph1.A', 'Inv.AC.I.Ph2.A', 'Inv.AC.I.Ph3.A', 'Inv.DC.P.MPTT1.W', 'Inv.DC.P.MPTT2.W', 'Inv.DC.U.MPTT1.V', 'Inv.DC.U.MPTT2.V', 'Inv.DC.I.MPTT1.A', 'Inv.DC.I.MPTT2.A', 'Inv.DC.R.Ohm']
# ==================================================
# 58: MID: MNTR|e33c50e4-7967-45d0-9f95-268a472c05b6, pv_size: 93980
# Gen.W
# metrics_name_list: ['Gen.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.I.Ph1.A']
# ==================================================
# 59: MID: MNTR|7603893, pv_size: 99880
# Gen.W
# Inv.DC.P.MPTT1.W
# Inv.DC.P.MPTT2.W
# Inv.DC.P.MPTT3.W
# Inv.DC.P.MPTT4.W
# Inv.DC.P.MPTT5.W
# Inv.DC.P.MPTT6.W
# Inv.DC.P.MPTT7.W
# Inv.DC.P.MPTT8.W
# Inv.DC.P.MPTT9.W
# Inv.DC.P.MPTT10.W
# Inv.DC.P.MPTT11.W
# Inv.DC.P.MPTT12.W
# metrics_name_list: ['Gen.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.U.Ph2.V', 'Inv.AC.U.Ph3.V', 'Inv.AC.I.Ph1.A', 'Inv.AC.I.Ph2.A', 'Inv.AC.I.Ph3.A', 'Inv.DC.P.MPTT1.W', 'Inv.DC.P.MPTT2.W', 'Inv.DC.P.MPTT3.W', 'Inv.DC.P.MPTT4.W', 'Inv.DC.P.MPTT5.W', 'Inv.DC.P.MPTT6.W', 'Inv.DC.P.MPTT7.W', 'Inv.DC.P.MPTT8.W', 'Inv.DC.P.MPTT9.W', 'Inv.DC.P.MPTT10.W', 'Inv.DC.P.MPTT11.W', 'Inv.DC.P.MPTT12.W', 'Inv.DC.U.MPTT1.V', 'Inv.DC.U.MPTT2.V', 'Inv.DC.U.MPTT3.V', 'Inv.DC.U.MPTT4.V', 'Inv.DC.U.MPTT5.V', 'Inv.DC.U.MPTT6.V', 'Inv.DC.U.MPTT7.V', 'Inv.DC.U.MPTT8.V', 'Inv.DC.U.MPTT9.V', 'Inv.DC.U.MPTT10.V', 'Inv.DC.U.MPTT11.V', 'Inv.DC.U.MPTT12.V', 'Inv.DC.I.MPTT1.A', 'Inv.DC.I.MPTT2.A', 'Inv.DC.I.MPTT3.A', 'Inv.DC.I.MPTT4.A', 'Inv.DC.I.MPTT5.A', 'Inv.DC.I.MPTT6.A', 'Inv.DC.I.MPTT7.A', 'Inv.DC.I.MPTT8.A', 'Inv.DC.I.MPTT9.A', 'Inv.DC.I.MPTT10.A', 'Inv.DC.I.MPTT11.A', 'Inv.DC.I.MPTT12.A', 'Inv.DC.R.Ohm']
# significant days: 6
# Gen.W None
# Inv.AC.U.Ph1.V AC.UV.Ph_significant
# Inv.AC.U.Ph2.V AC.UV.Ph_significant
# Inv.AC.U.Ph3.V AC.UV.Ph_significant
# Inv.AC.I.Ph1.A AC.IA.Ph_significant
# Inv.AC.I.Ph2.A AC.IA.Ph_significant
# Inv.AC.I.Ph3.A AC.IA.Ph_significant
# Inv.DC.P.MPTT1.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT2.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT3.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT4.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT5.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT6.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT7.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT8.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT9.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT10.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT11.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT12.W DC.PW.MPPT_significant
# Inv.DC.U.MPTT1.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT2.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT3.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT4.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT5.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT6.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT7.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT8.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT9.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT10.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT11.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT12.V DC.UV.MPPT_significant
# Inv.DC.I.MPTT1.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT2.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT3.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT4.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT5.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT6.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT7.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT8.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT9.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT10.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT11.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT12.A DC.IA.MPPT_significant
# Inv.DC.R.Ohm None
# ==================================================
# 60: MID: MNTR|2392158, pv_size: 24990
# Gen.W
# Inv.AC.P.Ph1.W
# Inv.AC.P.Ph2.W
# Inv.AC.P.Ph3.W
# Inv.DC.P.MPTT1.W
# Inv.DC.P.MPTT2.W
# metrics_name_list: ['Gen.W', 'Inv.AC.P.Ph1.W', 'Inv.AC.P.Ph2.W', 'Inv.AC.P.Ph3.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.U.Ph2.V', 'Inv.AC.U.Ph3.V', 'Inv.AC.I.Ph1.A', 'Inv.AC.I.Ph2.A', 'Inv.AC.I.Ph3.A', 'Inv.DC.P.MPTT1.W', 'Inv.DC.P.MPTT2.W', 'Inv.DC.U.MPTT1.V', 'Inv.DC.U.MPTT2.V', 'Inv.DC.I.MPTT1.A', 'Inv.DC.I.MPTT2.A', 'Inv.DC.R.Ohm']
# significant days: 4
# Gen.W None
# Inv.AC.P.Ph1.W AC.PW.Ph_significant
# Inv.AC.P.Ph2.W AC.PW.Ph_significant
# Inv.AC.P.Ph3.W AC.PW.Ph_significant
# Inv.AC.U.Ph1.V AC.UV.Ph_significant
# Inv.AC.U.Ph2.V AC.UV.Ph_significant
# Inv.AC.U.Ph3.V AC.UV.Ph_significant
# Inv.AC.I.Ph1.A AC.IA.Ph_significant
# Inv.AC.I.Ph2.A AC.IA.Ph_significant
# Inv.AC.I.Ph3.A AC.IA.Ph_significant
# Inv.DC.P.MPTT1.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT2.W DC.PW.MPPT_significant
# Inv.DC.U.MPTT1.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT2.V DC.UV.MPPT_significant
# Inv.DC.I.MPTT1.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT2.A DC.IA.MPPT_significant
# Inv.DC.R.Ohm None
# ==================================================
# 61: MID: MNTR|2582948, pv_size: 27770
# Gen.W
# Inv.AC.P.Ph1.W
# Inv.AC.P.Ph2.W
# Inv.AC.P.Ph3.W
# Inv.DC.P.MPTT1.W
# Inv.DC.P.MPTT2.W
# metrics_name_list: ['Gen.W', 'Inv.AC.P.Ph1.W', 'Inv.AC.P.Ph2.W', 'Inv.AC.P.Ph3.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.U.Ph2.V', 'Inv.AC.U.Ph3.V', 'Inv.AC.I.Ph1.A', 'Inv.AC.I.Ph2.A', 'Inv.AC.I.Ph3.A', 'Inv.DC.P.MPTT1.W', 'Inv.DC.P.MPTT2.W', 'Inv.DC.U.MPTT1.V', 'Inv.DC.U.MPTT2.V', 'Inv.DC.I.MPTT1.A', 'Inv.DC.I.MPTT2.A', 'Inv.DC.R.Ohm']
# ==================================================
# 62: MID: MNTR|dc65a555-d33b-48b8-bef4-9c8e129149cc, pv_size: 61220
# Gen.W
# metrics_name_list: ['Gen.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.I.Ph1.A', 'Inv.DC.U.MPTT1.V']
# ==================================================
# 63: MID: MNTR|be336ca7-0fcd-43a5-86ce-dc1d8ee8499a, pv_size: 86320
# Gen.W
# metrics_name_list: ['Gen.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.I.Ph1.A', 'Inv.DC.U.MPTT1.V']
# ==================================================
# 64: MID: MNTR|1c28dbc7-0380-4d63-87db-ff6af02ac8fa, pv_size: 95760
# Gen.W
# metrics_name_list: ['Gen.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.I.Ph1.A', 'Inv.DC.U.MPTT1.V']
# ==================================================
# 65: MID: MNTR|4a637324-749b-47c2-9f91-5ccc872d1416, pv_size: 93195
# Gen.W
# metrics_name_list: ['Gen.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.I.Ph1.A', 'Inv.DC.U.MPTT1.V']
# ==================================================
# 66: MID: MNTR|6039727, pv_size: 27750
# Gen.W
# Inv.AC.P.Ph1.W
# Inv.AC.P.Ph2.W
# Inv.AC.P.Ph3.W
# Inv.DC.P.MPTT1.W
# Inv.DC.P.MPTT2.W
# metrics_name_list: ['Gen.W', 'Inv.AC.P.Ph1.W', 'Inv.AC.P.Ph2.W', 'Inv.AC.P.Ph3.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.U.Ph2.V', 'Inv.AC.U.Ph3.V', 'Inv.AC.I.Ph1.A', 'Inv.AC.I.Ph2.A', 'Inv.AC.I.Ph3.A', 'Inv.DC.P.MPTT1.W', 'Inv.DC.P.MPTT2.W', 'Inv.DC.U.MPTT1.V', 'Inv.DC.U.MPTT2.V', 'Inv.DC.I.MPTT1.A', 'Inv.DC.I.MPTT2.A', 'Inv.DC.R.Ohm']
# significant days: 1
# Gen.W None
# Inv.AC.P.Ph1.W AC.PW.Ph_significant
# Inv.AC.P.Ph2.W AC.PW.Ph_significant
# Inv.AC.P.Ph3.W AC.PW.Ph_significant
# Inv.AC.U.Ph1.V AC.UV.Ph_significant
# Inv.AC.U.Ph2.V AC.UV.Ph_significant
# Inv.AC.U.Ph3.V AC.UV.Ph_significant
# Inv.AC.I.Ph1.A AC.IA.Ph_significant
# Inv.AC.I.Ph2.A AC.IA.Ph_significant
# Inv.AC.I.Ph3.A AC.IA.Ph_significant
# Inv.DC.P.MPTT1.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT2.W DC.PW.MPPT_significant
# Inv.DC.U.MPTT1.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT2.V DC.UV.MPPT_significant
# Inv.DC.I.MPTT1.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT2.A DC.IA.MPPT_significant
# Inv.DC.R.Ohm None
# ==================================================
# 67: MID: MNTR|2097653, pv_size: 27770
# Gen.W
# Inv.AC.P.Ph1.W
# Inv.AC.P.Ph2.W
# Inv.AC.P.Ph3.W
# Inv.DC.P.MPTT1.W
# Inv.DC.P.MPTT2.W
# metrics_name_list: ['Gen.W', 'Inv.AC.P.Ph1.W', 'Inv.AC.P.Ph2.W', 'Inv.AC.P.Ph3.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.U.Ph2.V', 'Inv.AC.U.Ph3.V', 'Inv.AC.I.Ph1.A', 'Inv.AC.I.Ph2.A', 'Inv.AC.I.Ph3.A', 'Inv.DC.P.MPTT1.W', 'Inv.DC.P.MPTT2.W', 'Inv.DC.U.MPTT1.V', 'Inv.DC.U.MPTT2.V', 'Inv.DC.I.MPTT1.A', 'Inv.DC.I.MPTT2.A', 'Inv.DC.R.Ohm']
# ==================================================
# 68: MID: MNTR|6306534, pv_size: 16650
# Gen.W
# Inv.AC.P.Ph1.W
# Inv.AC.P.Ph2.W
# Inv.AC.P.Ph3.W
# metrics_name_list: ['Gen.W', 'Inv.AC.P.Ph1.W', 'Inv.AC.P.Ph2.W', 'Inv.AC.P.Ph3.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.U.Ph2.V', 'Inv.AC.U.Ph3.V', 'Inv.AC.I.Ph1.A', 'Inv.AC.I.Ph2.A', 'Inv.AC.I.Ph3.A']
# ==================================================
# 69: MID: MNTR|7204b8dc-8166-444c-8483-4331b413d37c, pv_size: 78440
# Gen.W
# metrics_name_list: ['Gen.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.I.Ph1.A', 'Inv.DC.U.MPTT1.V']
# ==================================================
# 70: MID: MNTR|6145074, pv_size: 27770
# Gen.W
# Inv.AC.P.Ph1.W
# Inv.AC.P.Ph2.W
# Inv.AC.P.Ph3.W
# Inv.DC.P.MPTT1.W
# Inv.DC.P.MPTT2.W
# metrics_name_list: ['Gen.W', 'Inv.AC.P.Ph1.W', 'Inv.AC.P.Ph2.W', 'Inv.AC.P.Ph3.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.U.Ph2.V', 'Inv.AC.U.Ph3.V', 'Inv.AC.I.Ph1.A', 'Inv.AC.I.Ph2.A', 'Inv.AC.I.Ph3.A', 'Inv.DC.P.MPTT1.W', 'Inv.DC.P.MPTT2.W', 'Inv.DC.U.MPTT1.V', 'Inv.DC.U.MPTT2.V', 'Inv.DC.I.MPTT1.A', 'Inv.DC.I.MPTT2.A', 'Inv.DC.R.Ohm']
# significant days: 3
# Gen.W None
# Inv.AC.P.Ph1.W AC.PW.Ph_significant
# Inv.AC.P.Ph2.W AC.PW.Ph_significant
# Inv.AC.P.Ph3.W AC.PW.Ph_significant
# Inv.AC.U.Ph1.V AC.UV.Ph_significant
# Inv.AC.U.Ph2.V AC.UV.Ph_significant
# Inv.AC.U.Ph3.V AC.UV.Ph_significant
# Inv.AC.I.Ph1.A AC.IA.Ph_significant
# Inv.AC.I.Ph2.A AC.IA.Ph_significant
# Inv.AC.I.Ph3.A AC.IA.Ph_significant
# Inv.DC.P.MPTT1.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT2.W DC.PW.MPPT_significant
# Inv.DC.U.MPTT1.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT2.V DC.UV.MPPT_significant
# Inv.DC.I.MPTT1.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT2.A DC.IA.MPPT_significant
# Inv.DC.R.Ohm None
# ==================================================
# 71: MID: MNTR|1e8e3153-ab78-4aac-b0cb-8229dfe0d99e, pv_size: 27770
# Gen.W
# metrics_name_list: ['Gen.W']
# ==================================================
# 72: MID: MNTR|426e09a3-3863-440a-939f-b4b580688527, pv_size: 74240
# Gen.W
# metrics_name_list: ['Gen.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.I.Ph1.A', 'Inv.DC.U.MPTT1.V']
# ==================================================
# 73: MID: MNTR|2204236, pv_size: 16660
# Gen.W
# Inv.AC.P.Ph1.W
# Inv.AC.P.Ph2.W
# Inv.AC.P.Ph3.W
# Inv.DC.P.MPTT1.W
# Inv.DC.P.MPTT2.W
# metrics_name_list: ['Gen.W', 'Inv.AC.P.Ph1.W', 'Inv.AC.P.Ph2.W', 'Inv.AC.P.Ph3.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.U.Ph2.V', 'Inv.AC.U.Ph3.V', 'Inv.AC.I.Ph1.A', 'Inv.AC.I.Ph2.A', 'Inv.AC.I.Ph3.A', 'Inv.DC.P.MPTT1.W', 'Inv.DC.P.MPTT2.W', 'Inv.DC.U.MPTT1.V', 'Inv.DC.U.MPTT2.V', 'Inv.DC.I.MPTT1.A', 'Inv.DC.I.MPTT2.A', 'Inv.DC.R.Ohm']
# ==================================================
# 74: MID: MNTR|91f27ef5-8e85-420e-9e12-628d9e961c35, pv_size: 61220
# Gen.W
# metrics_name_list: ['Gen.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.I.Ph1.A', 'Inv.DC.U.MPTT1.V', 'Inv.DC.I.MPTT1.A']
# ==================================================
# 75: MID: MNTR|98c42ce0-7cd3-4edb-b430-7704c7ea0b64, pv_size: 17340
# Gen.W
# metrics_name_list: ['Gen.W']
# ==================================================
# 76: MID: MNTR|828240, pv_size: 27770
# Gen.W
# Inv.AC.P.Ph1.W
# Inv.AC.P.Ph2.W
# Inv.AC.P.Ph3.W
# Inv.DC.P.MPTT1.W
# Inv.DC.P.MPTT2.W
# metrics_name_list: ['Gen.W', 'Inv.AC.P.Ph1.W', 'Inv.AC.P.Ph2.W', 'Inv.AC.P.Ph3.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.U.Ph2.V', 'Inv.AC.U.Ph3.V', 'Inv.AC.I.Ph1.A', 'Inv.AC.I.Ph2.A', 'Inv.AC.I.Ph3.A', 'Inv.DC.P.MPTT1.W', 'Inv.DC.P.MPTT2.W', 'Inv.DC.U.MPTT1.V', 'Inv.DC.U.MPTT2.V', 'Inv.DC.I.MPTT1.A', 'Inv.DC.I.MPTT2.A', 'Inv.DC.R.Ohm']
# ==================================================
# 77: MID: MNTR|3987794, pv_size: 28807
# Gen.W
# Inv.AC.P.Ph1.W
# Inv.AC.P.Ph2.W
# Inv.AC.P.Ph3.W
# Inv.DC.P.MPTT1.W
# Inv.DC.P.MPTT2.W
# metrics_name_list: ['Gen.W', 'Inv.AC.P.Ph1.W', 'Inv.AC.P.Ph2.W', 'Inv.AC.P.Ph3.W', 'Inv.AC.U.Ph1.V', 'Inv.AC.U.Ph2.V', 'Inv.AC.U.Ph3.V', 'Inv.AC.I.Ph1.A', 'Inv.AC.I.Ph2.A', 'Inv.AC.I.Ph3.A', 'Inv.DC.P.MPTT1.W', 'Inv.DC.P.MPTT2.W', 'Inv.DC.U.MPTT1.V', 'Inv.DC.U.MPTT2.V', 'Inv.DC.I.MPTT1.A', 'Inv.DC.I.MPTT2.A', 'Inv.DC.R.Ohm']
# significant days: 29
# Gen.W None
# Inv.AC.P.Ph1.W AC.PW.Ph_significant
# Inv.AC.P.Ph2.W AC.PW.Ph_significant
# Inv.AC.P.Ph3.W AC.PW.Ph_significant
# Inv.AC.U.Ph1.V AC.UV.Ph_significant
# Inv.AC.U.Ph2.V AC.UV.Ph_significant
# Inv.AC.U.Ph3.V AC.UV.Ph_significant
# Inv.AC.I.Ph1.A AC.IA.Ph_significant
# Inv.AC.I.Ph2.A AC.IA.Ph_significant
# Inv.AC.I.Ph3.A AC.IA.Ph_significant
# Inv.DC.P.MPTT1.W DC.PW.MPPT_significant
# Inv.DC.P.MPTT2.W DC.PW.MPPT_significant
# Inv.DC.U.MPTT1.V DC.UV.MPPT_significant
# Inv.DC.U.MPTT2.V DC.UV.MPPT_significant
# Inv.DC.I.MPTT1.A DC.IA.MPPT_significant
# Inv.DC.I.MPTT2.A DC.IA.MPPT_significant
# Inv.DC.R.Ohm None
# more than 20 days are experienced significant difference
# Gen.W None
# Inv.AC.P.Ph1.W AC.PW.Ph_significant
# Inv.AC.P.Ph2.W AC.PW.Ph_significant
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
